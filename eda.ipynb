# %%
import pandas as pd

df = pd.read_csv('./data/temperature_data.csv')

df.timestamp = pd.to_datetime(df.timestamp)
df['year'] = df.timestamp.dt.year

df.groupby(['city', 'season'])['temperature'].agg(['mean', 'std']).xs('Beijing', level=0)


for (city, date, season), g in (

    df.groupby([
        'city',
        pd.Grouper(key='timestamp', freq='YE'),
        'season'
    ], sort=False)
):
    fig.add_trace(
        go.Scatter(
            x=g['timestamp'],
            y=g['temperature'],
            mode='lines',
            line=dict(color=season_colors[season]),
            showlegend=False
        )
    )
# Out:
#          city  timestamp  temperature  season  year
# 0    New York 2010-01-01    -1.789899  winter  2010
# 1    New York 2010-01-02     6.455782  winter  2010
# 2    New York 2010-01-03    -4.895588  winter  2010
# 3    New York 2010-01-04   -11.391631  winter  2010
# 4    New York 2010-01-05    -2.692336  winter  2010
# ..        ...        ...          ...     ...   ...
# 360  New York 2010-12-27     2.195262  winter  2010
# 361  New York 2010-12-28     7.440650  winter  2010
# 362  New York 2010-12-29     0.909203  winter  2010
# 363  New York 2010-12-30    -3.551921  winter  2010
# 364  New York 2010-12-31    -0.749091  winter  2010
#
# [90 rows x 5 columns]
#          city  timestamp  temperature  season  year
# 59   New York 2010-03-01    10.455867  spring  2010
# 60   New York 2010-03-02    11.256872  spring  2010
# 61   New York 2010-03-03    15.383292  spring  2010
# 62   New York 2010-03-04     2.858844  spring  2010
# 63   New York 2010-03-05    13.011551  spring  2010
# ...
